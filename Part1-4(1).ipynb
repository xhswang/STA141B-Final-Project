# %%
print("Part 1 analyze the top 10 series disease")
# Out:
# Part 1 analyze the top 10 series disease

# %%
import pandas as pd
import requests

# %%
import json
json_data = '''
{"@odata.context":"https://xmart-api-public.who.int/DEX_CMS/$metadata#GHE_FULL"
,"value":[{"DIM_COUNTRY_CODE":"USA"
,"DIM_YEAR_CODE":"2019"
,"DIM_AGEGROUP_CODE":"ALLAges"
,"DIM_SEX_CODE":"BTSX"
,"DIM_GHECAUSE_CODE":"1130"
,"ATTR_POPULATION_NUMERIC":329000000.00000000000000
,"DIM_GHECAUSE_TITLE":"Ischaemic heart disease",
"VAL_DALY_RATE100K_NUMERIC":2605.20000000000000,
"VAL_DALY_COUNT_NUMERIC":8571094.00000000000000,
"VAL_DEATHS_RATE100K_NUMERIC":153.47000000000000,
"VAL_DEATHS_COUNT_NUMERIC":504903.90000000000000},
{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019",
"DIM_AGEGROUP_CODE":"ALLAges",
"DIM_SEX_CODE":"BTSX",
"DIM_GHECAUSE_CODE":"950",
"ATTR_POPULATION_NUMERIC":329000000.00000000000000,
"DIM_GHECAUSE_TITLE":"Alzheimer disease and other dementias"
,"VAL_DALY_RATE100K_NUMERIC":1166.29000000000000
,"VAL_DALY_COUNT_NUMERIC":3837090.00000000000000
,"VAL_DEATHS_RATE100K_NUMERIC":87.29000000000000
,"VAL_DEATHS_COUNT_NUMERIC":287198.40000000000000}
,{"DIM_COUNTRY_CODE":"USA",
"DIM_YEAR_CODE":"2019",
"DIM_AGEGROUP_CODE":"ALLAges"
,"DIM_SEX_CODE":"BTSX",
"DIM_GHECAUSE_CODE":"1180",
"ATTR_POPULATION_NUMERIC":329000000.00000000000000,
"DIM_GHECAUSE_TITLE":"Chronic obstructive pulmonary disease",
"VAL_DALY_RATE100K_NUMERIC":1535.80000000000000,
"VAL_DALY_COUNT_NUMERIC":5052790.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":59.39000000000000,"VAL_DEATHS_COUNT_NUMERIC":195387.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"1140","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Stroke","VAL_DALY_RATE100K_NUMERIC":1055.79000000000000,"VAL_DALY_COUNT_NUMERIC":3473545.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":48.18000000000000,"VAL_DEATHS_COUNT_NUMERIC":158519.90000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"680","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Trachea, bronchus, lung cancers","VAL_DALY_RATE100K_NUMERIC":976.43000000000000,"VAL_DALY_COUNT_NUMERIC":3212446.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":47.27000000000000,"VAL_DEATHS_COUNT_NUMERIC":155532.60000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"1270","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Kidney diseases","VAL_DALY_RATE100K_NUMERIC":634.78000000000000,"VAL_DALY_COUNT_NUMERIC":2088442.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":26.10000000000000,"VAL_DEATHS_COUNT_NUMERIC":85860.85000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"870","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Drug use disorders","VAL_DALY_RATE100K_NUMERIC":1948.81000000000000,"VAL_DALY_COUNT_NUMERIC":6411582.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":22.62000000000000,"VAL_DEATHS_COUNT_NUMERIC":74434.62000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"1120","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Hypertensive heart disease","VAL_DALY_RATE100K_NUMERIC":408.04000000000000,"VAL_DALY_COUNT_NUMERIC":1342444.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":20.05000000000000,"VAL_DEATHS_COUNT_NUMERIC":65960.50000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"650","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"
40000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"1320","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Gynecological diseases","VAL_DALY_RATE100K_NUMERIC":264.57000000000000,"VAL_DALY_COUNT_NUMERIC":870428.80000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"85","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Genital herpes","VAL_DALY_RATE100K_NUMERIC":4.26000000000000,"VAL_DALY_COUNT_NUMERIC":14003.60000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"160","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Tetanus","VAL_DALY_RATE100K_NUMERIC":0.01000000000000,"VAL_DALY_COUNT_NUMERIC":36.70000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":2.10000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"285","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Cysticercosis","VAL_DALY_RATE100K_NUMERIC":2.16000000000000,"VAL_DALY_COUNT_NUMERIC":7110.33000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"830","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Depressive disorders","VAL_DALY_RATE100K_NUMERIC":807.57000000000000,"VAL_DALY_COUNT_NUMERIC":2656920.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"560","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Iodine deficiency","VAL_DALY_RATE100K_NUMERIC":2.63000000000000,"VAL_DALY_COUNT_NUMERIC":8666.24000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":1.11000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"570","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Vitamin A deficiency","VAL_DALY_RATE100K_NUMERIC":0.09000000000000,"VAL_DALY_COUNT_NUMERIC":306.15000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"250","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Schistosomiasis","VAL_DALY_RATE100K_NUMERIC":0.01000000000000,"VAL_DALY_COUNT_NUMERIC":36.96000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":1.14000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"260","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Leishmaniasis","VAL_DALY_RATE100K_NUMERIC":0.00000000000000,"VAL_DALY_COUNT_NUMERIC":0.17000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"240","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Chagas disease","VAL_DALY_RATE100K_NUMERIC":0.26000000000000,"VAL_DALY_COUNT_NUMERIC":839.16000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":4.41000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"70","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Gonorrhoea","VAL_DALY_RATE100K_NUMERIC":0.75000000000000,"VAL_DALY_COUNT_NUMERIC":2481.24000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":4.58000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"80","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Trichomoniasis","VAL_DALY_RATE100K_NUMERIC":4.62000000000000,"VAL_DALY_COUNT_NUMERIC":15203.82000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"220","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Malaria","VAL_DALY_RATE100K_NUMERIC":0.00000000000000,"VAL_DALY_COUNT_NUMERIC":8.32000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.12000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"230","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"African trypanosomiasis","VAL_DALY_RATE100K_NUMERIC":0.00000000000000,"VAL_DALY_COUNT_NUMERIC":0.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"60","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Chlamydia","VAL_DALY_RATE100K_NUMERIC":1.27000000000000,"VAL_DALY_COUNT_NUMERIC":4187.62000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"362","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Food-bourne trematodes","VAL_DALY_RATE100K_NUMERIC":0.00000000000000,"VAL_DALY_COUNT_NUMERIC":0.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"365","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Leprosy","VAL_DALY_RATE100K_NUMERIC":0.00000000000000,"VAL_DALY_COUNT_NUMERIC":9.51000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.33000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"300","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Dengue","VAL_DALY_RATE100K_NUMERIC":0.08000000000000,"VAL_DALY_COUNT_NUMERIC":261.89000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.19000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"140","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Diphtheria","VAL_DALY_RATE100K_NUMERIC":0.01000000000000,"VAL_DALY_COUNT_NUMERIC":26.72000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.30000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"310","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Trachoma","VAL_DALY_RATE100K_NUMERIC":0.00000000000000,"VAL_DALY_COUNT_NUMERIC":0.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"315","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Yellow fever","VAL_DALY_RATE100K_NUMERIC":0.00000000000000,"VAL_DALY_COUNT_NUMERIC":0.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"340","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Ascariasis","VAL_DALY_RATE100K_NUMERIC":0.00000000000000,"VAL_DALY_COUNT_NUMERIC":0.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"350","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Trichuriasis","VAL_DALY_RATE100K_NUMERIC":0.00000000000000,"VAL_DALY_COUNT_NUMERIC":0.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"150","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Measles","VAL_DALY_RATE100K_NUMERIC":0.00000000000000,"VAL_DALY_COUNT_NUMERIC":3.32000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"360","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Hookworm disease","VAL_DALY_RATE100K_NUMERIC":0.00000000000000,"VAL_DALY_COUNT_NUMERIC":0.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"130","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Whooping cough","VAL_DALY_RATE100K_NUMERIC":1.08000000000000,"VAL_DALY_COUNT_NUMERIC":3541.94000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":15.70000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"280","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Onchocerciasis","VAL_DALY_RATE100K_NUMERIC":0.00000000000000,"VAL_DALY_COUNT_NUMERIC":0.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2019","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"270","ATTR_POPULATION_NUMERIC":329000000.00000000000000,"DIM_GHECAUSE_TITLE":"Lymphatic filariasis","VAL_DALY_RATE100K_NUMERIC":0.00000000000000,"VAL_DALY_COUNT_NUMERIC":0.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000
,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000}]}
'''

# Parse JSON data
data = json.loads(json_data)

entries = []

for entry in data['value']:
    entry_dict = {
        "Country": entry['DIM_COUNTRY_CODE'],
        "Year": entry['DIM_YEAR_CODE'],
        "AgeGroup": entry['DIM_AGEGROUP_CODE'],
        "Sex": entry['DIM_SEX_CODE'],
        "CauseCode": entry['DIM_GHECAUSE_CODE'],
        "PopulationNumeric": entry['ATTR_POPULATION_NUMERIC'],
        "CauseTitle": entry['DIM_GHECAUSE_TITLE'],
        "DALYRate100K": entry['VAL_DALY_RATE100K_NUMERIC'],
        "DALYCount": entry['VAL_DALY_COUNT_NUMERIC'],
        "DeathsRate100K": entry['VAL_DEATHS_RATE100K_NUMERIC'],
        "DeathsCount": entry['VAL_DEATHS_COUNT_NUMERIC']
    }
    entries.append(entry_dict)

df = pd.DataFrame(entries)
df
# Out:
#     Country  Year AgeGroup   Sex CauseCode  PopulationNumeric  \
# 0       USA  2019  ALLAges  BTSX      1130        329000000.0
# 1       USA  2019  ALLAges  BTSX       950        329000000.0
# 2       USA  2019  ALLAges  BTSX      1180        329000000.0
# 3       USA  2019  ALLAges  BTSX      1140        329000000.0
# 4       USA  2019  ALLAges  BTSX       680        329000000.0
# ..      ...   ...      ...   ...       ...                ...
# 126     USA  2019  ALLAges  BTSX       150        329000000.0
# 127     USA  2019  ALLAges  BTSX       360        329000000.0
# 128     USA  2019  ALLAges  BTSX       130        329000000.0
# 129     USA  2019  ALLAges  BTSX       280        329000000.0
# 130     USA  2019  ALLAges  BTSX       270        329000000.0
#
#                                 CauseTitle  DALYRate100K   DALYCount  \
# 0                  Ischaemic heart disease       2605.20  8571094.00
# 1    Alzheimer disease and other dementias       1166.29  3837090.00
# ...

# %%
# !pip install plotnine
# Out:
# ...
#   Using cached plotnine-0.12.4-py3-none-any.whl (1.3 MB)
# ...
#   Using cached statsmodels-0.14.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
# ...
#   Using cached mizani-0.9.3-py3-none-any.whl (73 kB)
# ...
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.13.5
#     Uninstalling statsmodels-0.13.5:
#       Successfully uninstalled statsmodels-0.13.5
# ...

# %%
df_sorted = df.sort_values(by="DeathsCount", ascending=False)
# Select the top ten diseases
df_top10 = df_sorted.head(10)
df_top10
# Out:
#   Country  Year AgeGroup   Sex CauseCode  PopulationNumeric  \
# 0     USA  2019  ALLAges  BTSX      1130        329000000.0
# 1     USA  2019  ALLAges  BTSX       950        329000000.0
# 2     USA  2019  ALLAges  BTSX      1180        329000000.0
# 3     USA  2019  ALLAges  BTSX      1140        329000000.0
# 4     USA  2019  ALLAges  BTSX       680        329000000.0
# 5     USA  2019  ALLAges  BTSX      1270        329000000.0
# 6     USA  2019  ALLAges  BTSX       870        329000000.0
# 7     USA  2019  ALLAges  BTSX      1120        329000000.0
# 8     USA  2019  ALLAges  BTSX       650        329000000.0
# 9     USA  2019  ALLAges  BTSX       800        329000000.0
#
#                               CauseTitle  DALYRate100K  DALYCount  \
# 0                Ischaemic heart disease       2605.20  8571094.0
# 1  Alzheimer disease and other dementias       1166.29  3837090.0
# 2  Chronic obstructive pulmonary disease       1535.80  5052790.0
# ...

# %%
from plotnine import theme, element_text
from plotnine import ggplot, aes, geom_bar, theme_minimal, labs, geom_text, position_dodge, theme, element_text
plot = (
    ggplot(df_top10, aes(x='CauseTitle', y='DeathsCount', fill='CauseTitle')) +
    geom_bar(stat='identity', position=position_dodge(width=0.9), width=0.7) +  # Adjust width
    theme_minimal() +
    labs(x='Cause of Death', y='Death Count', title='Top 10 Causes of Death in the United States (2019)') +
    geom_text(aes(label='DeathsCount'), position=position_dodge(width=0.9), va='bottom', color='black', size=8) +
    theme(axis_text_x=element_text(rotation=45, hjust=1))  # Rotate x-axis labels
)

print(plot)

# %%
import json
json_data = '''
{"@odata.context":"https://xmart-api-public.who.int/DEX_CMS/$metadata#GHE_FULL","value":[{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2018","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"
000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":4.56000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2018","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"80","ATTR_POPULATION_NUMERIC":327000000.00000000000000,"DIM_GHECAUSE_TITLE":"Trichomoniasis","VAL_DALY_RATE100K_NUMERIC":4.63000000000000,"VAL_DALY_COUNT_NUMERIC":15132.42000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2018","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"85","ATTR_POPULATION_NUMERIC":327000000.00000000000000,"DIM_GHECAUSE_TITLE":"Genital herpes","VAL_DALY_RATE100K_NUMERIC":4.25000000000000,"VAL_DALY_COUNT_NUMERIC":13906.30000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2018","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"130","ATTR_POPULATION_NUMERIC":327000000.00000000000000,"DIM_GHECAUSE_TITLE":"Whooping cough","VAL_DALY_RATE100K_NUMERIC":1.06000000000000,"VAL_DALY_COUNT_NUMERIC":3456.96000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":15.32000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2018","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"140","ATTR_POPULATION_NUMERIC":327000000.00000000000000,"DIM_GHECAUSE_TITLE":"Diphtheria","VAL_DALY_RATE100K_NUMERIC":0.01000000000000,"VAL_DALY_COUNT_NUMERIC":26.09000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.30000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2018","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"150","ATTR_POPULATION_NUMERIC":327000000.00000000000000,"DIM_GHECAUSE_TITLE":"Measles","VAL_DALY_RATE100K_NUMERIC":0.00000000000000,"VAL_DALY_COUNT_NUMERIC":1.24000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2018","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"160","ATTR_POPULATION_NUMERIC":327000000.00000000000000,"DIM_GHECAUSE_TITLE":"Tetanus","VAL_DALY_RATE100K_NUMERIC":0.01000000000000,"VAL_DALY_COUNT_NUMERIC":36.07000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":2.07000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2018","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"360","ATTR_POPULATION_NUMERIC":327000000.00000000000000,"DIM_GHECAUSE_TITLE":"Hookworm disease","VAL_DALY_RATE100K_NUMERIC":0.00000000000000,"VAL_DALY_COUNT_NUMERIC":0.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2018","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"362","ATTR_POPULATION_NUMERIC":327000000.00000000000000,"DIM_GHECAUSE_TITLE":"Food-bourne trematodes","VAL_DALY_RATE100K_NUMERIC":0.00000000000000,"VAL_DALY_COUNT_NUMERIC":0.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2018","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"365","ATTR_POPULATION_NUMERIC":327000000.00000000000000,"DIM_GHECAUSE_TITLE":"Leprosy","VAL_DALY_RATE100K_NUMERIC":0.00000000000000,"VAL_DALY_COUNT_NUMERIC":9.48000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.33000000000000}]}'''
#Parse JSON data
data = json.loads(json_data)

entries = []

for entry in data['value']:
    entry_dict = {
        "Country": entry['DIM_COUNTRY_CODE'],
        "Year": entry['DIM_YEAR_CODE'],
        "AgeGroup": entry['DIM_AGEGROUP_CODE'],
        "Sex": entry['DIM_SEX_CODE'],
        "CauseCode": entry['DIM_GHECAUSE_CODE'],
        "PopulationNumeric": entry['ATTR_POPULATION_NUMERIC'],
        "CauseTitle": entry['DIM_GHECAUSE_TITLE'],
        "DALYRate100K": entry['VAL_DALY_RATE100K_NUMERIC'],
        "DALYCount": entry['VAL_DALY_COUNT_NUMERIC'],
        "DeathsRate100K": entry['VAL_DEATHS_RATE100K_NUMERIC'],
        "DeathsCount": entry['VAL_DEATHS_COUNT_NUMERIC']
    }
    entries.append(entry_dict)

df18 = pd.DataFrame(entries)

# %%
df_sorted = df18.sort_values(by="DeathsCount", ascending=False)
# Select the top ten diseases
df_top11 = df_sorted.head(10)
df_top11
# Out:
#   Country  Year AgeGroup   Sex CauseCode  PopulationNumeric  \
# 0     USA  2018  ALLAges  BTSX      1130        327000000.0
# 1     USA  2018  ALLAges  BTSX       950        327000000.0
# 2     USA  2018  ALLAges  BTSX      1180        327000000.0
# 3     USA  2018  ALLAges  BTSX      1140        327000000.0
# 4     USA  2018  ALLAges  BTSX       680        327000000.0
# 5     USA  2018  ALLAges  BTSX      1270        327000000.0
# 6     USA  2018  ALLAges  BTSX       870        327000000.0
# 7     USA  2018  ALLAges  BTSX      1120        327000000.0
# 8     USA  2018  ALLAges  BTSX       650        327000000.0
# 9     USA  2018  ALLAges  BTSX       800        327000000.0
#
#                               CauseTitle  DALYRate100K  DALYCount  \
# 0                Ischaemic heart disease       2573.14  8414166.0
# 1  Alzheimer disease and other dementias       1134.00  3708195.0
# 2  Chronic obstructive pulmonary disease       1503.90  4917737.0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df_top10 is your DataFrame containing the top 10 causes of death
# You can adjust this based on how you obtained the top 10 data
disease_labels = ['Isacheamic HD', 'Dementia', 'COPD', 'Stroke', 'Lung Cancers',
                   'Kidney D', 'Drug Disorders', 'Hypertensive HD',
                   'Colon+ Rectum', 'Diabetes']

# Assuming df_top10 is your DataFrame containing the top 10 causes of death
# You can adjust this based on how you obtained the top 10 data
colors = sns.color_palette('husl', n_colors=len(disease_labels))

plt.figure(figsize=(12, 8))
bars = plt.bar(disease_labels, df_top11['DeathsCount'], color=colors)
plt.xlabel('Cause of Death')
plt.ylabel('Death Count')
plt.title('Top 10 Causes of Death in the United States (2018)')

# Add annotations beside the figures
for bar, label, count in zip(bars, disease_labels, df_top11['DeathsCount']):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.2, bar.get_height() + 5000, f'{label}\n{count:.0f}', ha='center', color='black')

plt.show()

# %%
import json
json_data ='''
{"@odata.context":"https://xmart-api-public.who.int/DEX_CMS/$metadata#GHE_FULL","value":[{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2017","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"1130","ATTR_POPULATION_NUMERIC":325000000.00000000000000,"DIM_GHECAUSE_TITLE":"Ischaemic heart disease","VAL_DALY_RATE100K_NUMERIC":2527.93000000000000,"VAL_DALY_COUNT_NUMERIC":8215764.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":147.43000000000000,"VAL_DEATHS_COUNT_NUMERIC":479159.60000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2017","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"950","ATTR_POPULATION_NUMERIC":325000000.00000000000000,"DIM_GHECAUSE_TITLE":"Alzheimer disease and other dementias","VAL_DALY_RATE100K_NUMERIC":1092.23000000000000,"VAL_DALY_COUNT_NUMERIC":3549763.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":81.46000000000000,"VAL_DEATHS_COUNT_NUMERIC":264737.50000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2017","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"1180","ATTR_POPULATION_NUMERIC":325000000.00000000000000,"DIM_GHECAUSE_TITLE":"Chronic obstructive pulmonary disease","VAL_DALY_RATE100K_NUMERIC":1467.86000000000000,"VAL_DALY_COUNT_NUMERIC":4770545.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":56.09000000000000,"VAL_DEATHS_COUNT_NUMERIC":182293.70000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2017","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"1140","ATTR_POPULATION_NUMERIC":325000000.00000000000000,"DIM_GHECAUSE_TITLE":"Stroke","VAL_DALY_RATE100K_NUMERIC":1042.76000000000000,"VAL_DALY_COUNT_NUMERIC":3388983.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":47.31000000000000,"VAL_DEATHS_COUNT_NUMERIC":153763.70000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2017","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"680","ATTR_POPULATION_NUMERIC":325000000.00000000000000,"DIM_GHECAUSE_TITLE":"Trachea, bronchus, lung cancers","VAL_DALY_RATE100K_NUMERIC":944.12000000000000,"VAL_DALY_COUNT_NUMERIC":3068388.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":45.32000000000000,"VAL_DEATHS_COUNT_NUMERIC":147293.60000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2017","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"1270","ATTR_POPULATION_NUMERIC":325000000.00000000000000,"DIM_GHECAUSE_TITLE":"Kidney diseases","VAL_DALY_RATE100K_NUMERIC":613.90000000000000,"VAL_DALY_COUNT_NUMERIC":1995173.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":24.71000000000000,"VAL_DEATHS_COUNT_NUMERIC":80294.95000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2017","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"870","ATTR_POPULATION_NUMERIC":325000000.00000000000000,"DIM_GHECAUSE_TITLE":"Drug use disorders","VAL_DALY_RATE100K_NUMERIC":1859.86000000000000,"VAL_DALY_COUNT_NUMERIC":6044560.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":21.08000000000000,"VAL_DEATHS_COUNT_NUMERIC":68504.17000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2017","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"1120","ATTR_POPULATION_NUMERIC":325000000.00000000000000,"DIM_GHECAUSE_TITLE":"Hypertensive heart disease","VAL_DALY_RATE100K_NUMERIC":422.34000000000000,"VAL_DALY_COUNT_NUMERIC":1372612.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":20.96000000000000,"VAL_DEATHS_COUNT_NUMERIC":68116.05000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2017","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"650","ATTR_POPULATION_NUMERIC":325000000.00000000000000,"DIM_GHECAUSE_TITLE":"Colon and rectum cancers","VAL_DALY_RATE100K_NUMERIC":435.78000000000000,"VAL_DALY_COUNT_NUMERIC":1416286.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":18.80000000000000,"VAL_DEATHS_COUNT_NUMERIC":61110.49000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2017","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"800","ATTR_POPULATION_NUMERIC":325000000.00000000000000,"DIM_GHECAUSE_TITLE":"Diabetes mellitus","VAL_DALY_RATE100K_NUMERIC":1229.78000000000000,"VAL_DALY_COUNT_NUMERIC":3996798.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":17.96000000000000,"VAL_DEATHS_COUNT_NUMERIC":58364.15000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2017","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"390","ATTR_POPULATION_NUMERIC":325000000.00000000000000,"DIM_GHECAUSE_TITLE":"Lower respiratory infections","VAL_DALY_RATE100K_NUMERIC":297.74000000000000,"VAL_DALY_COUNT_NUMERIC":967657.30000000000000,"VAL_DEATHS_RATE100K_NUMERIC":17.52000000000000,"VAL_DEATHS_COUNT_NUMERIC":56942.81000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2017","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"1610","ATTR_POPULATION_NUMERIC":325000000.00000000000000,"DIM_GHECAUSE_TITLE":"Self-harm","VAL_DALY_RATE100K_NUMERIC":720.52000000000000,"VAL_DALY_COUNT_NUMERIC":2341681.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC
ATTR_POPULATION_NUMERIC":325000000.00000000000000,"DIM_GHECAUSE_TITLE":"Chagas disease","VAL_DALY_RATE100K_NUMERIC":0.25000000000000,"VAL_DALY_COUNT_NUMERIC":827.47000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":4.90000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2017","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"250","ATTR_POPULATION_NUMERIC":325000000.00000000000000,"DIM_GHECAUSE_TITLE":"Schistosomiasis","VAL_DALY_RATE100K_NUMERIC":0.01000000000000,"VAL_DALY_COUNT_NUMERIC":19.81000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":1.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2017","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"260","ATTR_POPULATION_NUMERIC":325000000.00000000000000,"DIM_GHECAUSE_TITLE":"Leishmaniasis","VAL_DALY_RATE100K_NUMERIC":0.00000000000000,"VAL_DALY_COUNT_NUMERIC":0.17000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2017","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"60","ATTR_POPULATION_NUMERIC":325000000.00000000000000,"DIM_GHECAUSE_TITLE":"Chlamydia","VAL_DALY_RATE100K_NUMERIC":1.29000000000000,"VAL_DALY_COUNT_NUMERIC":4189.22000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2017","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"70","ATTR_POPULATION_NUMERIC":325000000.00000000000000,"DIM_GHECAUSE_TITLE":"Gonorrhoea","VAL_DALY_RATE100K_NUMERIC":0.72000000000000,"VAL_DALY_COUNT_NUMERIC":2352.29000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":2.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2017","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"80","ATTR_POPULATION_NUMERIC":325000000.00000000000000,"DIM_GHECAUSE_TITLE":"Trichomoniasis","VAL_DALY_RATE100K_NUMERIC":4.63000000000000,"VAL_DALY_COUNT_NUMERIC":15052.88000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2017","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"85","ATTR_POPULATION_NUMERIC":325000000.00000000000000,"DIM_GHECAUSE_TITLE":"Genital herpes","VAL_DALY_RATE100K_NUMERIC":4.25000000000000,"VAL_DALY_COUNT_NUMERIC":13804.54000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2017","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"130","ATTR_POPULATION_NUMERIC":325000000.00000000000000,"DIM_GHECAUSE_TITLE":"Whooping cough","VAL_DALY_RATE100K_NUMERIC":1.02000000000000,"VAL_DALY_COUNT_NUMERIC":3323.17000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":15.88000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2017","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"140","ATTR_POPULATION_NUMERIC":325000000.00000000000000,"DIM_GHECAUSE_TITLE":"Diphtheria","VAL_DALY_RATE100K_NUMERIC":0.01000000000000,"VAL_DALY_COUNT_NUMERIC":24.77000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.28000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2017","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"150","ATTR_POPULATION_NUMERIC":325000000.00000000000000,"DIM_GHECAUSE_TITLE":"Measles","VAL_DALY_RATE100K_NUMERIC":0.00000000000000,"VAL_DALY_COUNT_NUMERIC":0.31000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2017","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"160","ATTR_POPULATION_NUMERIC":325000000.00000000000000,"DIM_GHECAUSE_TITLE":"Tetanus","VAL_DALY_RATE100K_NUMERIC":0.00000000000000,"VAL_DALY_COUNT_NUMERIC":16.04000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":1.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2017","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"270","ATTR_POPULATION_NUMERIC":325000000.00000000000000,"DIM_GHECAUSE_TITLE":"Lymphatic filariasis","VAL_DALY_RATE100K_NUMERIC":0.00000000000000,"VAL_DALY_COUNT_NUMERIC":0.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2017","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"280","ATTR_POPULATION_NUMERIC":325000000.00000000000000,"DIM_GHECAUSE_TITLE":"Onchocerciasis","VAL_DALY_RATE100K_NUMERIC":0.00000000000000,"VAL_DALY_COUNT_NUMERIC":0.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2017","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"285","ATTR_POPULATION_NUMERIC":325000000.00000000000000,"DIM_GHECAUSE_TITLE":"Cysticercosis","VAL_DALY_RATE100K_NUMERIC":2.50000000000000,"VAL_DALY_COUNT_NUMERIC":8129.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2017","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"830","ATTR_POPULATION_NUMERIC":325000000.00000000000000,"DIM_GHECAUSE_TITLE":"Depressive disorders","VAL_DALY_RATE100K_NUMERIC":809.88000000000000,"VAL_DALY_COUNT_NUMERIC":2632106.00000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2017","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"560","ATTR_POPULATION_NUMERIC":325000000.00000000000000,"DIM_GHECAUSE_TITLE":"Iodine deficiency","VAL_DALY_RATE100K_NUMERIC":2.64000000000000,"VAL_DALY_COUNT_NUMERIC":8579.75000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000},{"DIM_COUNTRY_CODE":"USA","DIM_YEAR_CODE":"2017","DIM_AGEGROUP_CODE":"ALLAges","DIM_SEX_CODE":"BTSX","DIM_GHECAUSE_CODE":"570","ATTR_POPULATION_NUMERIC":325000000.00000000000000,"DIM_GHECAUSE_TITLE":"Vitamin A deficiency","VAL_DALY_RATE100K_NUMERIC":0.10000000000000,"VAL_DALY_COUNT_NUMERIC":316.83000000000000,"VAL_DEATHS_RATE100K_NUMERIC":0.00000000000000,"VAL_DEATHS_COUNT_NUMERIC":0.00000000000000}]}
'''
#Parse JSON data
data = json.loads(json_data)

entries = []

for entry in data['value']:
    entry_dict = {
        "Country": entry['DIM_COUNTRY_CODE'],
        "Year": entry['DIM_YEAR_CODE'],
        "AgeGroup": entry['DIM_AGEGROUP_CODE'],
        "Sex": entry['DIM_SEX_CODE'],
        "CauseCode": entry['DIM_GHECAUSE_CODE'],
        "PopulationNumeric": entry['ATTR_POPULATION_NUMERIC'],
        "CauseTitle": entry['DIM_GHECAUSE_TITLE'],
        "DALYRate100K": entry['VAL_DALY_RATE100K_NUMERIC'],
        "DALYCount": entry['VAL_DALY_COUNT_NUMERIC'],
        "DeathsRate100K": entry['VAL_DEATHS_RATE100K_NUMERIC'],
        "DeathsCount": entry['VAL_DEATHS_COUNT_NUMERIC']
    }
    entries.append(entry_dict)

df17 = pd.DataFrame(entries)

# %%
df_sorted = df17.sort_values(by="DeathsCount", ascending=False)
df_sorted
# Out:
#     Country  Year AgeGroup   Sex CauseCode  PopulationNumeric  \
# 0       USA  2017  ALLAges  BTSX      1130        325000000.0
# 1       USA  2017  ALLAges  BTSX       950        325000000.0
# 2       USA  2017  ALLAges  BTSX      1180        325000000.0
# 3       USA  2017  ALLAges  BTSX      1140        325000000.0
# 4       USA  2017  ALLAges  BTSX       680        325000000.0
# ..      ...   ...      ...   ...       ...                ...
# 107     USA  2017  ALLAges  BTSX       340        325000000.0
# 108     USA  2017  ALLAges  BTSX       350        325000000.0
# 109     USA  2017  ALLAges  BTSX       360        325000000.0
# 110     USA  2017  ALLAges  BTSX       362        325000000.0
# 130     USA  2017  ALLAges  BTSX       570        325000000.0
#
#                                 CauseTitle  DALYRate100K   DALYCount  \
# 0                  Ischaemic heart disease       2527.93  8215764.00
# 1    Alzheimer disease and other dementias       1092.23  3549763.00
# ...

# %%
# Select the top ten diseases for 2017
df_top17 = df_sorted.head(10)
import matplotlib.pyplot as plt
import seaborn as sns
# select the parameters
disease_labels = ['Isacheamic HD', 'Dementia', 'COPD', 'Stroke', 'Lung Cancers',
                   'Kidney D', 'Drug Disorders', 'Hypertensive HD',
                   'Colon+ Rectum', 'Diabetes']

#plot the trend 
colors = sns.color_palette('husl', n_colors=len(disease_labels))

plt.figure(figsize=(12, 8))
bars = plt.bar(disease_labels, df_top17['DeathsCount'], color=colors)
plt.xlabel('Cause of Death')
plt.ylabel('Death Count')
plt.title('Top 10 Causes of Death in the United States (2017)')

# Add annotations beside the figures
for bar, label, count in zip(bars, disease_labels, df_top17['DeathsCount']):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.2, bar.get_height() + 5000, f'{label}\n{count:.0f}', ha='center', color='black')

plt.show()

# %%
df4 = df17.sort_values(by="DeathsCount", ascending=False)
df5 = df18.sort_values(by="DeathsCount", ascending=False)
df6 =  df.sort_values(by="DeathsCount", ascending=False)
import matplotlib.pyplot as plt
import seaborn as sns
# Combine into one DF
combined_df = pd.concat([df4, df5, df6])
# Filter Ischaemic HD
heart_disease_df = combined_df[combined_df['CauseTitle'].str.contains('Ischaemic Heart', case=False)]
# Create a line plot to show the trend
plt.figure(figsize=(12, 8))
sns.lineplot(data=heart_disease_df, x='Year', y='DeathsCount', hue='CauseTitle', marker='o')
plt.title('Trend of Ischaemic Heart Disease Deaths Over 3 Years')
plt.xlabel('Year')
plt.ylabel('Deaths Count')
plt.legend(title='Cause Title')
plt.show()

# %%
print("Part 2 analyzes the Ischaemic Heart diseaes through Age, Gender and Region")
# Out:
# Part 2 analyzes the Ischaemic Heart diseaes through Age, Gender and Region

# %%
import pandas as pd
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt

# %%
def get_web_content():
    file_path = input('please input the path of the html file')
    tables = pd.read_html(file_path)
    testlist = tables[0][1]
    testlist = testlist.values.tolist()
    from_index = testlist.index('<tbody>')
    to_index = testlist.index('</tbody>') + 1
    contentlist = testlist[from_index:to_index]
    merged_string = "\n".join(contentlist)
    return merged_string

# %%
file_path = "test2.html"
tables = pd.read_html(file_path)
testlist = tables[0][1]
testlist = testlist.values.tolist()
from_where = testlist.index('<tbody>')
to_where = testlist.index('</tbody>') + 1
contentlist = testlist[from_where:to_where]
merged_string = "\n".join(contentlist)

# %%
soup = BeautifulSoup(merged_string, 'html.parser')

# Extract data from table
data = []
for tr in soup.find_all('tr'):
    row = []
    for th in tr.find_all('th'):
        row.append(th.text.strip())
    for td in tr.find_all('td'):
        row.append(td.text.strip())
    data.append(row)

# Create DataFrame
columns = ['State', 'Gender', 'age-group', 'Death', 'population', 'death per 100000']  # Replace with actual column names
df = pd.DataFrame(data, columns=columns)

df
# Out:
#             State  Gender      age-group       Death population  \
# 0    Alabama (01)  Female    60-64 years          10  3,019,968
# 1    Alabama (01)  Female    65-69 years          19  2,554,038
# 2    Alabama (01)  Female    70-74 years          30  2,093,061
# 3    Alabama (01)  Female    75-79 years          27  1,652,154
# 4    Alabama (01)  Female    80-84 years          37  1,208,648
# ..            ...     ...            ...         ...        ...
# 914  Wyoming (56)  Female          Total          43  5,918,086
# 915  Wyoming (56)    Male    75-79 years          11    135,754
# 916  Wyoming (56)    Male          Total          54  6,117,057
# 917  Wyoming (56)   Total             97  12,035,143        0.8
# 918         Total  43,977  6,746,356,647         0.7       None
#
#     death per 100000
# 0         Unreliable
# 1         Unreliable
# 2                1.4
# 3                1.6
# 4                3.1
# ..               ...
# 914              0.7
# ...

# %%
df_filtered = df[df['age-group'].str.lower() == 'total']
df_filtered[df_filtered['death per 100000'] == 'Unreliable']
test_df = df_filtered[df_filtered['State'] != 'District of Columbia (11)']
test_df['population'] = test_df['population'].str.replace(',', '').astype(float)
test_df['death per 100000'] = test_df['death per 100000'].astype(float)
test_df
# Out:
# <ipython-input-77-78c21fc67d3d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <ipython-input-77-78c21fc67d3d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                   State  Gender age-group Death  population  death per 100000
# 7          Alabama (01)  Female     Total   210  53441699.0               0.4
# 18         Alabama (01)    Male     Total   273  50162467.0               0.5
# 20          Alaska (02)  Female     Total    23   7335857.0               0.3
# ...

# %%
plt.figure(figsize=(12, 6))
for gender in test_df['Gender'].unique():
    df_gender = test_df[test_df['Gender'] == gender]
    plt.plot(df_gender['State'], df_gender['death per 100000'], marker='o', label=gender)

plt.xlabel('State')
plt.ylabel('Number of Deaths per 100,000')
plt.title('Number of Deaths per 100,000 by State and Gender')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
df_female = test_df[test_df['Gender'] == 'Female']
df_male = test_df[test_df['Gender'] == 'Male']

df_merged = pd.merge(df_female, df_male, on='State', suffixes=('_Female', '_Male'))

count_states_higher_female = (df_merged['death per 100000_Female'] > df_merged['death per 100000_Male']).sum()

print(f'there are {count_states_higher_female} states that have female death rate higher than male death rate')
# Out:
# there are 5 states that have female death rate higher than male death rate

# %%
df_state_total = df[df['Gender'] == 'Total']
df_state_total= df_state_total.rename(columns = {'population' : 'Death per 100000'})
df_state_total = df_state_total.drop('death per 100000',axis = 1)
df_state_total['Death per 100000'] = df_state_total['Death per 100000'].astype(float)
df_state_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 19 to 917
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             51 non-null     object
#  1   Gender            51 non-null     object
#  2   age-group         51 non-null     object
#  3   Death             51 non-null     object
#  4   Death per 100000  51 non-null     float64
# dtypes: float64(1), object(4)
# memory usage: 2.4+ KB

# %%
# Plotting
plt.figure(figsize=(15, 8))
plt.scatter(df_state_total['State'], df_state_total['Death per 100000'], color='blue')
plt.xlabel('State')
plt.ylabel('Death per 100000')
plt.title('Death per 100000 by State')
plt.xticks(rotation=90)  # Rotate the x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
df_okla = df[df['State'] == 'Oklahoma (40)']
df_okla
# Out:
#              State  Gender    age-group       Death      population  \
# 646  Oklahoma (40)  Female  40-44 years          34       2,672,371
# 647  Oklahoma (40)  Female  45-49 years          62       2,720,650
# 648  Oklahoma (40)  Female  50-54 years         126       2,699,860
# 649  Oklahoma (40)  Female  55-59 years         143       2,557,976
# 650  Oklahoma (40)  Female  60-64 years         175       2,237,768
# 651  Oklahoma (40)  Female  65-69 years         185       1,885,699
# 652  Oklahoma (40)  Female  70-74 years         197       1,544,457
# 653  Oklahoma (40)  Female  75-79 years         200       1,233,182
# 654  Oklahoma (40)  Female  80-84 years         304         912,831
# 655  Oklahoma (40)  Female  85-89 years         363  Not Applicable
# 656  Oklahoma (40)  Female  90-94 years         291  Not Applicable
# 657  Oklahoma (40)  Female  95-99 years         155  Not Applicable
# 658  Oklahoma (40)  Female   100+ years          38  Not Applicable
# ...

# %%
print("Part 3 Analyze risk factors")
# Out:
# Part 3 Analyze risk factors

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt

api_url = "https://ephtracking.cdc.gov/apigateway/api/v1/getCoreHolder/1362/1/all/all/1/2021,2020,2019,2018,2017,2016,2015,2014,2013,2012,2011/0/0"

# Make a GET request to the API
response = requests.get(api_url)

# Check if the request was successful
if response.status_code == 200:
    data = response.json()
    
else:
    print(f"Error: {response.status_code}, {response.text}")

# %%
print("Smoking data in 2021")
# Out:
# Smoking data in 2021

# %%
response = requests.get(api_url)

# Check if the request was successful
if response.status_code == 200:
    data = response.json()

    # Create a Pandas DataFrame
    df = pd.DataFrame(data['tableResult'])

    # Filter the DataFrame for the year 2021
    df_2021_S = df[df['year'] == '2021']

    # Select only the 'year', 'geo' (state), and 'dataValue' 
    df_2021_S_selected = df_2021_S[['year', 'geo', 'dataValue']]
    
else:
    print(f"Error: {response.status_code}, {response.text}")

df_2021_S_selected
# Out:
#      year                       geo dataValue
# 10   2021                   Alabama      17.2
# 21   2021                    Alaska      17.1
# 32   2021                   Arizona      13.1
# 43   2021                  Arkansas      21.1
# 54   2021                California       8.8
# 65   2021                  Colorado      12.0
# 76   2021               Connecticut      11.1
# 87   2021                  Delaware      13.4
# 98   2021      District of Columbia       9.5
# 109  2021                   Florida      None
# 120  2021                   Georgia      15.0
# 131  2021                    Hawaii      10.1
# 142  2021                     Idaho      13.3
# 153  2021                  Illinois      12.0
# 164  2021                   Indiana      17.3
# 175  2021                      Iowa      14.6
# 186  2021                    Kansas      15.6
# 197  2021                  Kentucky      19.6
# 208  2021                 Louisiana      19.5
# ...

# %%
# Convert 'dataValue' to numeric
df_2021_S_selected = df_2021_S_selected.dropna(subset=['dataValue'])
df_2021_S_selected['dataValue'] = pd.to_numeric(df_2021_S_selected['dataValue'], errors='coerce')

# Sort the DataFrame by 'dataValue'
df_2021_S_selected = df_2021_S_selected.sort_values(by='dataValue')

# Display the DataFrame for the year 2021 with selected columns
df_2021_S_selected

# Draw a histogram based on states with sorted values
plt.figure(figsize=(12, 6))
plt.bar(df_2021_S_selected['geo'], df_2021_S_selected['dataValue'])
plt.xlabel('State')
plt.ylabel('Percent')
plt.title('Distribution of Percent Values by State in 2021')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-5-dd40be88aa49>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021_S_selected['dataValue'] = pd.to_numeric(df_2021_S_selected['dataValue'], errors='coerce')

# %%
print("High cholesterol data")
# Out:
# High cholesterol data

# %%
api_url2 = "https://ephtracking.cdc.gov/apigateway/api/v1/getCoreHolder/1360/1/all/all/1/2021/0/0"

# Make a GET request to the API
response = requests.get(api_url2)

# Check if the request was successful
if response.status_code == 200:
    data = response.json()
    
else:
    print(f"Error: {response.status_code}, {response.text}")

# %%
response = requests.get(api_url2)

# Check if the request was successful
if response.status_code == 200:
    data = response.json()

    # Create a DataFrame
    df = pd.DataFrame(data['tableResult'])

    # Filter the DataFrame for the year 2021
    df_2021 = df[df['year'] == '2021']

    # Select only the 'year', 'geo' (state), and 'dataValue'
    df_2021_selected = df_2021[['year', 'geo', 'dataValue']]

else:
    print(f"Error: {response.status_code}, {response.text}")

df_2021_selected
# Out:
#     year                       geo dataValue
# 0   2021                   Alabama      40.0
# 1   2021                    Alaska      32.0
# 2   2021                   Arizona      35.0
# 3   2021                  Arkansas      37.2
# 4   2021                California      33.8
# 5   2021                  Colorado      31.6
# 6   2021               Connecticut      34.9
# 7   2021                  Delaware      37.7
# 8   2021      District of Columbia      30.6
# 9   2021                   Florida      None
# 10  2021                   Georgia      36.6
# 11  2021                    Hawaii      34.9
# 12  2021                     Idaho      33.4
# 13  2021                  Illinois      32.3
# 14  2021                   Indiana      35.6
# 15  2021                      Iowa      35.4
# 16  2021                    Kansas      38.8
# 17  2021                  Kentucky      37.5
# 18  2021                 Louisiana      37.7
# 19  2021                     Maine      35.4
# ...

# %%
# Convert 'dataValue' to numeric
df_2021_selected = df_2021_selected.dropna(subset=['dataValue'])
df_2021_selected['dataValue'] = pd.to_numeric(df_2021_selected['dataValue'], errors='coerce')

# Sort the DataFrame by 'dataValue'
df_2021_selected = df_2021_selected.sort_values(by='dataValue')

# Display the sorted DataFrame for the year 2021 with selected columns
df_2021_selected

# Draw a histogram based on states with sorted values
plt.figure(figsize=(12, 6))
plt.bar(df_2021_selected['geo'], df_2021_selected['dataValue'])
plt.xlabel('State')
plt.ylabel('Percent')
plt.title('Distribution of Percent Values by State in 2021')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-8-1f267b800c8c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021_selected['dataValue'] = pd.to_numeric(df_2021_selected['dataValue'], errors='coerce')

# %%
print("High blood pressure data")
# Out:
# High blood pressure data

# %%
api_url3 = "https://ephtracking.cdc.gov/apigateway/api/v1/getCoreHolder/1358/1/all/all/1/2021/0/0"

# Make a GET request to the API
response = requests.get(api_url3)

# Check if the request was successful
if response.status_code == 200:
    data = response.json()
    
else:
    print(f"Error: {response.status_code}, {response.text}")

# %%
print("High blood pressure data in 2021")
# Out:
# High blood pressure data in 2021

# %%
response = requests.get(api_url3)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    data = response.json()

    # Create a Pandas DataFrame
    df = pd.DataFrame(data['tableResult'])

    # Filter the DataFrame for the year 2021
    df_2021_B = df[df['year'] == '2021']

    # Select only the 'year', 'geo' (state), and 'dataValue' 
    df_2021_B_selected = df_2021_B[['year', 'geo', 'dataValue']]

else:
    print(f"Error: {response.status_code}, {response.text}")

df_2021_B_selected
# Out:
#     year                       geo dataValue
# 0   2021                   Alabama      42.7
# 1   2021                    Alaska      30.4
# 2   2021                   Arizona      30.9
# 3   2021                  Arkansas      40.7
# 4   2021                California      27.9
# 5   2021                  Colorado      26.0
# 6   2021               Connecticut      31.6
# 7   2021                  Delaware      36.2
# 8   2021      District of Columbia      27.9
# 9   2021                   Florida      None
# 10  2021                   Georgia      36.6
# 11  2021                    Hawaii      29.8
# 12  2021                     Idaho      30.5
# 13  2021                  Illinois      30.0
# 14  2021                   Indiana      34.5
# 15  2021                      Iowa      31.4
# 16  2021                    Kansas      34.3
# 17  2021                  Kentucky      39.9
# 18  2021                 Louisiana      40.2
# 19  2021                     Maine      33.9
# ...

# %%
# Convert 'dataValue' to numeric
df_2021_B_selected = df_2021_B_selected.dropna(subset=['dataValue'])
df_2021_B_selected['dataValue'] = pd.to_numeric(df_2021_B_selected['dataValue'], errors='coerce')

# Sort the DataFrame by 'dataValue'
df_2021_B_selected = df_2021_B_selected.sort_values(by='dataValue')

# Display the sorted DataFrame for the year 2021 with selected columns
df_2021_B_selected

# Draw a histogram based on states with sorted values
plt.figure(figsize=(12, 6))
plt.bar(df_2021_B_selected['geo'], df_2021_B_selected['dataValue'])
plt.xlabel('State')
plt.ylabel('Percent')
plt.title('Distribution of Percent Values by State in 2021')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-11-8d1f28841fee>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021_B_selected['dataValue'] = pd.to_numeric(df_2021_B_selected['dataValue'], errors='coerce')

# %%
# Merge the three DataFrames based on the 'geo' and 'year' columns
df_combined1 = pd.merge(df_2021_S_selected, df_2021_selected, on=['year', 'geo'], suffixes=('_S', '_C'))
df_combined2 = pd.merge(df_combined1, df_2021_B_selected, on=['year', 'geo'], suffixes=('_S', '_B'))

# Display the combined DataFrame
df_combined2
# Out:
#     year                   geo  dataValue_S  dataValue_C  dataValue
# 0   2021                  Utah          7.2         31.6       26.6
# 1   2021            California          8.8         33.8       27.9
# 2   2021           Puerto Rico          9.1         41.4       41.8
# 3   2021  District of Columbia          9.5         30.6       27.9
# 4   2021                Hawaii         10.1         34.9       29.8
# 5   2021              Maryland         10.1         37.6       34.5
# 6   2021         Massachusetts         10.6         35.7       29.9
# 7   2021            New Jersey         10.7         37.0       31.1
# 8   2021            Washington         10.8         33.4       29.6
# 9   2021           Connecticut         11.1         34.9       31.6
# 10  2021              Colorado         12.0         31.6       26.0
# 11  2021              New York         12.0         36.2       30.5
# 12  2021              Illinois         12.0         32.3       30.0
# ...

# %%
import matplotlib.pyplot as plt

# Draw a line plot based on states for each factor
plt.figure(figsize=(12, 6))
plt.plot(df_combined2['geo'], df_combined2['dataValue_S'], label='Factor Smoking', marker='o')
plt.plot(df_combined2['geo'], df_combined2['dataValue_C'], label='Factor High Cholesterol', marker='o')
plt.plot(df_combined2['geo'], df_combined2['dataValue'], label='Factor High Blood Pressure', marker='o')

plt.xlabel('State')
plt.ylabel('Data Value')
plt.title('Line Plot Based on Three Main Factors Lead to Heart Diseases')
plt.legend()
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
